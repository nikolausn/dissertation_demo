# %%
import pandas as pd
import numpy as np

# %%
airbnb_pd = pd.read_csv("chicago_listings.csv")

# %%
subset_1 = pd.read_csv("id_list_subset_dataset_1.csv")

# %%
subset_1.id.tolist()
# Out:
# [25879,
#  37738,
#  189821,
#  207218,
#  220333,
#  289884,
#  350347,
#  464581,
#  640841,
#  668262,
#  727847,
#  739495,
#  929914,
#  1321332,
#  1356190,
#  1392594,
#  1591370,
#  1614802,
#  1623463,
#  1678422,
#  1772920,
#  1773021,
#  1773025,
#  2103986,
#  2189522,
#  2305194,
#  2305230,
#  2543231,
#  2611538,
#  2907500,
#  3053081,
#  3172794,
#  3434136,
#  3570616,
#  3696178,
#  3870522,
#  4067870,
#  4150121,
#  4156913,
#  4243309,
#  4394093,
#  4731523,
#  4793938,
#  4840753,
#  4923963,
#  4925062,
#  4930338,
#  5095370,
#  5126218,
#  5297152,
#  5537683,
#  5576190,
#  5694572,
#  5785758,
#  5804791,
#  5805991,
#  5850897,
#  6014028,
#  6014128,
#  6057908,
#  6277018,
#  6396451,
#  6472628,
#  6528867,
#  6588681,
#  6612044,
#  6863178,
#  6994290,
#  7116810,
#  7241887,
#  7274926,
#  7384649,
#  7389646,
#  7572706,
#  7583774,
#  7630479,
#  7637490,
#  7802208,
#  7875516,
#  7919400,
#  8053055,
#  8098937,
#  8098969,
#  8339990,
# ...

# %%
airbnb_pd[airbnb_pd.id.isin(subset_1.id.tolist())].to_csv("airbnb_sample1_a.csv")

# %%
subset_2 = pd.read_csv("id_list_subset_dataset_2.csv")

subset_2.id.tolist()
# Out:
# [7126,
#  84042,
#  145659,
#  264547,
#  290155,
#  372929,
#  404792,
#  532862,
#  585356,
#  634310,
#  724895,
#  1027463,
#  1185749,
#  1195259,
#  1304049,
#  1461451,
#  1921670,
#  2062638,
#  2139407,
#  2298310,
#  2320027,
#  2471876,
#  2583929,
#  2679456,
#  2730613,
#  2731202,
#  2819982,
#  2824585,
#  2832376,
#  2874486,
#  2907112,
#  3267902,
#  3590692,
#  3666681,
#  3761023,
#  3946324,
#  4417718,
#  4503414,
#  4632510,
#  4689162,
#  4777997,
#  4803582,
#  5185790,
#  5205377,
#  5210931,
#  5321981,
#  5359984,
#  5980645,
#  5996942,
#  6045978,
#  6166734,
#  6229085,
#  6378085,
#  6419072,
#  6423299,
#  6447131,
#  6480445,
#  6504170,
#  6528967,
#  6654182,
#  6716705,
#  6757098,
#  6764230,
#  6764833,
#  6782452,
#  6793653,
#  6897078,
#  6957805,
#  6967492,
#  7416788,
#  7649812,
#  7692835,
#  7713352,
#  7718819,
#  7760721,
#  7783924,
#  7825308,
#  7947804,
#  8072314,
#  8272970,
#  8472766,
#  8633981,
#  8735904,
#  8802052,
# ...

# %%
airbnb_pd[airbnb_pd.id.isin(subset_2.id.tolist())].to_csv("airbnb_sample2_a.csv")
