# %%
import pandas as pd
import numpy as np

# %%
#split training testing variation

# %%
original_ds = pd.read_csv("chicago_listings.csv")

# %%
import os
from airbnb_baseline import baseline_clean
from airbnb_baseline_average import baseline_clean_average
from airbnb_curator_c1 import airbnb_curator_c1
from airbnb_curator_c2 import airbnb_curator_c2
from airbnb_curator_c3 import airbnb_curator_c3
from airbnb_curator_merge import airbnb_curator_merge

# %%
for x in os.listdir("split_variation"):
    print(x)
    for y in os.listdir(f"split_variation/{x}"):
        if y.startswith("train_noise") and y.find("cleaned")<0:
            print(y)
            airbnb_pd = pd.read_csv(f"split_variation/{x}/{y}")
            airbnb_pd = baseline_clean(airbnb_pd)
            airbnb_pd.to_csv(f"split_variation/{x}/{y}_cleaned_baseline.csv",index=False)
# Out:
# split_4
# train_noise_40.csv
# ...

# %%
for x in os.listdir("split_variation"):
    print(x)
    for y in os.listdir(f"split_variation/{x}"):
        if y.startswith("train_noise") and y.find("cleaned")<0:
            print(y)
            airbnb_pd = pd.read_csv(f"split_variation/{x}/{y}")
            airbnb_pd = baseline_clean_average(airbnb_pd)
            airbnb_pd.to_csv(f"split_variation/{x}/{y}_cleaned_baselineAverage.csv",index=False)
# Out:
# split_4
# train_noise_40.csv
# ...

# %%
for x in os.listdir("split_variation"):
    print(x)
    for y in os.listdir(f"split_variation/{x}"):
        if y.startswith("train_noise") and y.find("cleaned")<0:
            print(y)
            airbnb_pd = pd.read_csv(f"split_variation/{x}/{y}")
            airbnb_pd = airbnb_curator_c1(airbnb_pd)
            airbnb_pd.to_csv(f"split_variation/{x}/{y}_cleaned_curatorC1.csv",index=False)
# Out:
# split_4
# train_noise_40.csv
# ...

# %%
for x in os.listdir("split_variation"):
    print(x)
    for y in os.listdir(f"split_variation/{x}"):
        if y.startswith("train_noise") and y.find("cleaned")<0:
            print(y)
            airbnb_pd = pd.read_csv(f"split_variation/{x}/{y}")
            airbnb_pd = airbnb_curator_c2(airbnb_pd)
            airbnb_pd.to_csv(f"split_variation/{x}/{y}_cleaned_curatorC2.csv",index=False)
# Out:
# split_4
# train_noise_40.csv
# ...

# %%
for x in os.listdir("split_variation"):
    print(x)
    for y in os.listdir(f"split_variation/{x}"):
        if y.startswith("train_noise") and y.find("cleaned")<0:
            print(y)
            airbnb_pd = pd.read_csv(f"split_variation/{x}/{y}")
            airbnb_pd = airbnb_curator_c3(airbnb_pd)
            airbnb_pd.to_csv(f"split_variation/{x}/{y}_cleaned_curatorC3.csv",index=False)
# Out:
# split_4
# train_noise_40.csv
# ...

# %%
for x in os.listdir("split_variation"):
    print(x)
    for y in os.listdir(f"split_variation/{x}"):
        if y.startswith("train_noise") and y.find("cleaned")<0:
            print(y)
            airbnb_pd = pd.read_csv(f"split_variation/{x}/{y}")
            airbnb_pd = airbnb_curator_merge(airbnb_pd)
            airbnb_pd.to_csv(f"split_variation/{x}/{y}_cleaned_curatorMerge.csv",index=False)
# Out:
# split_4
# train_noise_40.csv
# score: 1.0
# score: 1.1468852459016394
# ...
